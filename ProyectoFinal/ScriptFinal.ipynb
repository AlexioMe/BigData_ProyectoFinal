# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, read_csv
# Import the standard libraries for the data preprocessing

import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = read_csv('URGENCIAS.txt', sep='|', index_col=['ID'])
df.tail()
# Out:
#                CLUES   fechaalta  EDAD  CVEEDAD  SEXO  ENTRESIDENCIA  \
# ID
# 7074267  DFSSA004026  2022-01-08    86        5     2             99
# 7074268  DFSSA004026  2022-01-08    11        5     1             99
# 7074269  DFSSA004026  2022-01-08    30        5     1             99
# 7074270  DFSSA004026  2022-01-09    26        5     2             99
# 7074271  DFSSA004026  2022-01-09    28        5     2             99
#
#          MUNRESIDENCIA DERHAB  TIPOURGENCIA  MOTATE  ...  MP  AFECPRIN  IRA  \
# ID                                                   ...
# 7074267            998     99             2       2  ...   8      U071    8
# 7074268            998     99             2       2  ...   8      J46X    8
# 7074269            998     99             2       2  ...   8      U072    8
# 7074270            998     99             2       2  ...   8      U072    8
# 7074271            998     99             2       2  ...   8      U072    8
#
#         PLANEDA  SOBRESEDA fechaingreso  HORASESTANCIA MES_ESTADISTICO  \
# ID
# 7074267       8        NaN   2022-01-08          99:99               1
# 7074268       8        NaN   2022-01-08          99:99               1
# 7074269       8        NaN   2022-01-08          99:99               1
# 7074270       8        NaN   2022-01-09          99:99               1
# 7074271       8        NaN   2022-01-09          99:99               1
#
#         hora_ingreso  hora_alta
# ID
# 7074267        99:99      99:99
# 7074268        99:99      99:99
# 7074269        99:99      99:99
# 7074270        99:99      99:99
# 7074271        99:99      99:99
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7074271 entries, 1 to 7074271
# Data columns (total 22 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   CLUES            object
#  1   fechaalta        object
#  2   EDAD             int64
#  3   CVEEDAD          int64
#  4   SEXO             int64
#  5   ENTRESIDENCIA    int64
#  6   MUNRESIDENCIA    int64
#  7   DERHAB           object
#  8   TIPOURGENCIA     int64
#  9   MOTATE           int64
#  10  TIPOCAMA         int64
#  11  ENVIADOA         int64
#  12  MP               int64
#  13  AFECPRIN         object
#  14  IRA              int64
#  15  PLANEDA          object
#  16  SOBRESEDA        float64
#  17  fechaingreso     object
#  18  HORASESTANCIA    object
#  19  MES_ESTADISTICO  int64
#  20  hora_ingreso     object
#  21  hora_alta        object
# dtypes: float64(1), int64(12), object(9)
# memory usage: 1.2+ GB

# %%
df.describe()
# Out:
#                EDAD       CVEEDAD          SEXO  ENTRESIDENCIA  MUNRESIDENCIA  \
# count  7.074271e+06  7.074271e+06  7.074271e+06   7.074271e+06   7.074271e+06
# mean   3.696580e+01  4.979300e+00  1.637430e+00   1.806222e+01   1.039066e+02
# std    8.273697e+01  4.216177e-01  4.818178e-01   1.514540e+01   2.358963e+02
# min    1.000000e+00  2.000000e+00  0.000000e+00   0.000000e+00   1.000000e+00
# 25%    1.700000e+01  5.000000e+00  1.000000e+00   1.000000e+01   1.000000e+01
# 50%    2.600000e+01  5.000000e+00  2.000000e+00   1.500000e+01   3.000000e+01
# 75%    4.300000e+01  5.000000e+00  2.000000e+00   2.400000e+01   7.600000e+01
# max    9.990000e+02  9.000000e+00  3.000000e+00   9.900000e+01   9.990000e+02
#
#        TIPOURGENCIA        MOTATE      TIPOCAMA      ENVIADOA            MP  \
# count  7.074271e+06  7.074271e+06  7.074271e+06  7.074271e+06  7.074271e+06
# mean   1.685357e+00  2.381992e+00  3.115970e+00  3.390392e+00  7.981585e+00
# std    4.643736e-01  9.883304e-01  2.018668e+00  1.219035e+00  3.420143e-01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  2.000000e+00  3.000000e+00  3.000000e+00  8.000000e+00
# 50%    2.000000e+00  2.000000e+00  3.000000e+00  4.000000e+00  8.000000e+00
# 75%    2.000000e+00  3.000000e+00  3.000000e+00  4.000000e+00  8.000000e+00
# max    2.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00  8.000000e+00
#
#                 IRA     SOBRESEDA  MES_ESTADISTICO
# count  7.074271e+06  69694.000000     7.074271e+06
# mean   7.728220e+00      2.612047     6.739933e+00
# std    1.328623e+00      1.266553     3.386046e+00
# min    1.000000e+00      0.000000     1.000000e+00
# 25%    8.000000e+00      2.000000     4.000000e+00
# 50%    8.000000e+00      3.000000     7.000000e+00
# 75%    8.000000e+00      3.000000     1.000000e+01
# max    8.000000e+00     20.000000     1.200000e+01

# %%
df.isna().sum()/len(df)*100
# Out:
# CLUES               0.000000
# fechaalta           0.000000
# EDAD                0.000000
# CVEEDAD             0.000000
# SEXO                0.000000
# ENTRESIDENCIA       0.000000
# MUNRESIDENCIA       0.000000
# DERHAB              0.000000
# TIPOURGENCIA        0.000000
# MOTATE              0.000000
# TIPOCAMA            0.000000
# ENVIADOA            0.000000
# MP                  0.000000
# AFECPRIN            0.000000
# IRA                 0.000000
# PLANEDA             0.000000
# SOBRESEDA          99.014824
# fechaingreso        0.000000
# HORASESTANCIA       0.000000
# MES_ESTADISTICO     0.000000
# hora_ingreso        0.000000
# hora_alta           0.000000
# dtype: float64

# %%
#SOBRESEDA 99% de NULL, la vamos a eliminar
df = df.drop(['SOBRESEDA'], axis=1)

# %%
df.describe().style.background_gradient(cmap='RdYlBu')
# Out:
# <style type="text/css">
# #T_08ae2_row0_col0, #T_08ae2_row0_col1, #T_08ae2_row0_col2, #T_08ae2_row0_col3, #T_08ae2_row0_col4, #T_08ae2_row0_col5, #T_08ae2_row0_col6, #T_08ae2_row0_col7, #T_08ae2_row0_col8, #T_08ae2_row0_col9, #T_08ae2_row0_col10, #T_08ae2_row0_col11 {
#   background-color: #313695;
#   color: #f1f1f1;
# }
# #T_08ae2_row1_col0, #T_08ae2_row1_col1, #T_08ae2_row1_col2, #T_08ae2_row1_col3, #T_08ae2_row1_col4, #T_08ae2_row1_col5, #T_08ae2_row1_col6, #T_08ae2_row1_col7, #T_08ae2_row1_col8, #T_08ae2_row1_col9, #T_08ae2_row1_col10, #T_08ae2_row1_col11, #T_08ae2_row2_col0, #T_08ae2_row2_col1, #T_08ae2_row2_col2, #T_08ae2_row2_col3, #T_08ae2_row2_col4, #T_08ae2_row2_col5, #T_08ae2_row2_col6, #T_08ae2_row2_col7, #T_08ae2_row2_col8, #T_08ae2_row2_col9, #T_08ae2_row2_col10, #T_08ae2_row2_col11, #T_08ae2_row3_col0, #T_08ae2_row3_col1, #T_08ae2_row3_col2, #T_08ae2_row3_col3, #T_08ae2_row3_col4, #T_08ae2_row3_col5, #T_08ae2_row3_col6, #T_08ae2_row3_col7, #T_08ae2_row3_col8, #T_08ae2_row3_col9, #T_08ae2_row3_col10, #T_08ae2_row3_col11, #T_08ae2_row4_col0, #T_08ae2_row4_col1, #T_08ae2_row4_col2, #T_08ae2_row4_col3, #T_08ae2_row4_col4, #T_08ae2_row4_col5, #T_08ae2_row4_col6, #T_08ae2_row4_col7, #T_08ae2_row4_col8, #T_08ae2_row4_col9, #T_08ae2_row4_col10, #T_08ae2_row4_col11, #T_08ae2_row5_col0, #T_08ae2_row5_col1, #T_08ae2_row5_col2, #T_08ae2_row5_col3, #T_08ae2_row5_col4, #T_08ae2_row5_col5, #T_08ae2_row5_col6, #T_08ae2_row5_col7, #T_08ae2_row5_col8, #T_08ae2_row5_col9, #T_08ae2_row5_col10, #T_08ae2_row5_col11, #T_08ae2_row6_col0, #T_08ae2_row6_col1, #T_08ae2_row6_col2, #T_08ae2_row6_col3, #T_08ae2_row6_col4, #T_08ae2_row6_col5, #T_08ae2_row6_col6, #T_08ae2_row6_col7, #T_08ae2_row6_col8, #T_08ae2_row6_col9, #T_08ae2_row6_col10, #T_08ae2_row6_col11, #T_08ae2_row7_col0, #T_08ae2_row7_col1, #T_08ae2_row7_col2, #T_08ae2_row7_col3, #T_08ae2_row7_col4, #T_08ae2_row7_col5, #T_08ae2_row7_col6, #T_08ae2_row7_col7, #T_08ae2_row7_col8, #T_08ae2_row7_col9, #T_08ae2_row7_col10, #T_08ae2_row7_col11 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_08ae2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08ae2_level0_col0" class="col_heading level0 col0" >EDAD</th>
#       <th id="T_08ae2_level0_col1" class="col_heading level0 col1" >CVEEDAD</th>
#       <th id="T_08ae2_level0_col2" class="col_heading level0 col2" >SEXO</th>
#       <th id="T_08ae2_level0_col3" class="col_heading level0 col3" >ENTRESIDENCIA</th>
#       <th id="T_08ae2_level0_col4" class="col_heading level0 col4" >MUNRESIDENCIA</th>
#       <th id="T_08ae2_level0_col5" class="col_heading level0 col5" >TIPOURGENCIA</th>
#       <th id="T_08ae2_level0_col6" class="col_heading level0 col6" >MOTATE</th>
#       <th id="T_08ae2_level0_col7" class="col_heading level0 col7" >TIPOCAMA</th>
#       <th id="T_08ae2_level0_col8" class="col_heading level0 col8" >ENVIADOA</th>
#       <th id="T_08ae2_level0_col9" class="col_heading level0 col9" >MP</th>
#       <th id="T_08ae2_level0_col10" class="col_heading level0 col10" >IRA</th>
#       <th id="T_08ae2_level0_col11" class="col_heading level0 col11" >MES_ESTADISTICO</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08ae2_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_08ae2_row0_col0" class="data row0 col0" >7074271.000000</td>
#       <td id="T_08ae2_row0_col1" class="data row0 col1" >7074271.000000</td>
#       <td id="T_08ae2_row0_col2" class="data row0 col2" >7074271.000000</td>
#       <td id="T_08ae2_row0_col3" class="data row0 col3" >7074271.000000</td>
#       <td id="T_08ae2_row0_col4" class="data row0 col4" >7074271.000000</td>
#       <td id="T_08ae2_row0_col5" class="data row0 col5" >7074271.000000</td>
#       <td id="T_08ae2_row0_col6" class="data row0 col6" >7074271.000000</td>
#       <td id="T_08ae2_row0_col7" class="data row0 col7" >7074271.000000</td>
#       <td id="T_08ae2_row0_col8" class="data row0 col8" >7074271.000000</td>
#       <td id="T_08ae2_row0_col9" class="data row0 col9" >7074271.000000</td>
#       <td id="T_08ae2_row0_col10" class="data row0 col10" >7074271.000000</td>
#       <td id="T_08ae2_row0_col11" class="data row0 col11" >7074271.000000</td>
#     </tr>
#     <tr>
#       <th id="T_08ae2_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_08ae2_row1_col0" class="data row1 col0" >36.965802</td>
#       <td id="T_08ae2_row1_col1" class="data row1 col1" >4.979300</td>
#       <td id="T_08ae2_row1_col2" class="data row1 col2" >1.637430</td>
#       <td id="T_08ae2_row1_col3" class="data row1 col3" >18.062219</td>
#       <td id="T_08ae2_row1_col4" class="data row1 col4" >103.906581</td>
#       <td id="T_08ae2_row1_col5" class="data row1 col5" >1.685357</td>
#       <td id="T_08ae2_row1_col6" class="data row1 col6" >2.381992</td>
#       <td id="T_08ae2_row1_col7" class="data row1 col7" >3.115970</td>
#       <td id="T_08ae2_row1_col8" class="data row1 col8" >3.390392</td>
#       <td id="T_08ae2_row1_col9" class="data row1 col9" >7.981585</td>
#       <td id="T_08ae2_row1_col10" class="data row1 col10" >7.728220</td>
#       <td id="T_08ae2_row1_col11" class="data row1 col11" >6.739933</td>
#     </tr>
#     <tr>
#       <th id="T_08ae2_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_08ae2_row2_col0" class="data row2 col0" >82.736971</td>
#       <td id="T_08ae2_row2_col1" class="data row2 col1" >0.421618</td>
#       <td id="T_08ae2_row2_col2" class="data row2 col2" >0.481818</td>
#       <td id="T_08ae2_row2_col3" class="data row2 col3" >15.145399</td>
#       <td id="T_08ae2_row2_col4" class="data row2 col4" >235.896316</td>
#       <td id="T_08ae2_row2_col5" class="data row2 col5" >0.464374</td>
#       <td id="T_08ae2_row2_col6" class="data row2 col6" >0.988330</td>
#       <td id="T_08ae2_row2_col7" class="data row2 col7" >2.018668</td>
#       <td id="T_08ae2_row2_col8" class="data row2 col8" >1.219035</td>
#       <td id="T_08ae2_row2_col9" class="data row2 col9" >0.342014</td>
#       <td id="T_08ae2_row2_col10" class="data row2 col10" >1.328623</td>
#       <td id="T_08ae2_row2_col11" class="data row2 col11" >3.386046</td>
#     </tr>
#     <tr>
#       <th id="T_08ae2_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_08ae2_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_08ae2_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_08ae2_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_08ae2_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_08ae2_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_08ae2_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_08ae2_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_08ae2_row3_col7" class="data row3 col7" >1.000000</td>
#       <td id="T_08ae2_row3_col8" class="data row3 col8" >1.000000</td>
#       <td id="T_08ae2_row3_col9" class="data row3 col9" >1.000000</td>
#       <td id="T_08ae2_row3_col10" class="data row3 col10" >1.000000</td>
#       <td id="T_08ae2_row3_col11" class="data row3 col11" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_08ae2_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_08ae2_row4_col0" class="data row4 col0" >17.000000</td>
#       <td id="T_08ae2_row4_col1" class="data row4 col1" >5.000000</td>
#       <td id="T_08ae2_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_08ae2_row4_col3" class="data row4 col3" >10.000000</td>
#       <td id="T_08ae2_row4_col4" class="data row4 col4" >10.000000</td>
#       <td id="T_08ae2_row4_col5" class="data row4 col5" >1.000000</td>
#       <td id="T_08ae2_row4_col6" class="data row4 col6" >2.000000</td>
#       <td id="T_08ae2_row4_col7" class="data row4 col7" >3.000000</td>
#       <td id="T_08ae2_row4_col8" class="data row4 col8" >3.000000</td>
#       <td id="T_08ae2_row4_col9" class="data row4 col9" >8.000000</td>
#       <td id="T_08ae2_row4_col10" class="data row4 col10" >8.000000</td>
#       <td id="T_08ae2_row4_col11" class="data row4 col11" >4.00000

# %%
#Exportamos a CSV
dfResumen = df.describe()
dfResumen.to_csv('ResumenDatos.csv')

# %%
#Histograma de edades post limpieza

plt.figure(figsize=(12, 6))
plt.hist(df['EDAD'], bins=25, edgecolor='black')


#Rotamos etiquetas
plt.xticks(rotation=45, ha="right")

plt.show()

# %%
#Cargamos Data Set de Catalogo
dfCat = read_csv('CAT_CIE_10_2021.csv')

# %%
dfCat.head()
# Out:
#    CONSECUTIVO LETRA CLAVE                              NOMBRE  \
# 0            1    A"   A00                             CÓLERA"
# 1            2    A"  A000  CÓLERA DEBIDO A VIBRIO CHOLERAE 01
# 2            3    A"  A001  CÓLERA DEBIDO A VIBRIO CHOLERAE 01
# 3            4    A"  A009                              CÓLERA
# 4            5    A"   A01    FIEBRES TIFOIDEA Y PARATIFOIDEA"
#
#               CODIGOX LSEX LINF LSUP TRIVIAL ERRADICADO  ...  \
# 0                 NO"  NO"  NO"  NO"     NO"        NO"  ...
# 1   BIOTIPO CHOLERAE"  NO"  NO"  NO"     NO"        NO"  ...
# 2     BIOTIPO EL TOR"  NO"  NO"  NO"     NO"        NO"  ...
# 3    NO ESPECIFICADO"  NO"  NO"  NO"     NO"        NO"  ...
# 4                 NO"  NO"  NO"  NO"     NO"        NO"  ...
#
#   DESCRIPCION_MM_SUBGRUPO Unnamed: 74 Unnamed: 75 Unnamed: 76 Unnamed: 77  \
# 0                     NO"         NaN         NaN         NaN         NaN
# 1                     NO"         NO"         NaN         NaN         NaN
# 2                     NO"         NO"         NaN         NaN         NaN
# 3                     NO"         NO"         NaN         NaN         NaN
# 4                     NO"         NaN         NaN         NaN         NaN
#
#   Unnamed: 78 Unnamed: 79 Unnamed: 80 Unnamed: 81 Unnamed: 82
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 83 columns]

# %%
#Extraemos claves del Catalogo
dfCat_subset = dfCat[['CLAVE', 'NOMBRE']]

#Lo usamos para Mapear el dataset principal
df['AFECPRIN'] = df['AFECPRIN'].map(dfCat_subset.set_index('CLAVE')['NOMBRE'])

df.head()
# Out:
#           CLUES   fechaalta  EDAD  CVEEDAD  SEXO  ENTRESIDENCIA  \
# ID
# 1   TSSSA003732  2022-10-25     7        5     1             28
# 2   ZSSSA013172  2022-11-08    22        5     2              0
# 3   ZSSSA001016  2022-11-05    10        4     2             32
# 4   ZSSSA000695  2022-10-26    17        5     1             32
# 5   ZSSSA000572  2022-11-02    18        5     2             32
#
#     MUNRESIDENCIA DERHAB  TIPOURGENCIA  MOTATE  ...  ENVIADOA  MP  \
# ID                                              ...
# 1              22     11             2       2  ...         4   8
# 2             999      0             1       1  ...         2   8
# 3              36      0             1       2  ...         4   8
# 4              22      0             2       2  ...         4   8
# 5              19     11             2       2  ...         4   8
#
#                                              AFECPRIN IRA  PLANEDA  \
# ID
# 1   GASTROENTERITIS Y COLITIS DE ORIGEN NO ESPECIF...   8        8
# 2       DOLOR ABDOMINAL LOCALIZADO EN PARTE SUPERIOR"   8        8
# 3                                    FARINGITIS AGUDA   2        8
# 4   CONTUSIÓN DE OTRAS PARTES DE LA MUÑECA Y DE LA...   8        8
# 5     SUPERVISIÓN DE EMBARAZO NORMAL NO ESPECIFICADO"   8        8
#
#    fechaingreso HORASESTANCIA MES_ESTADISTICO  hora_ingreso hora_alta
# ID
# 1    2022-10-25        000:13              10         13:37     13:50
# 2    2022-11-07        012:40              11         19:40     08:20
# 3    2022-11-05        000:15              11         15:15     15:30
# 4    2022-10-26        000:54              10         10:30     11:24
# 5    2022-11-02        000:29              11         06:41     07:10
#
# [5 rows x 21 columns]

# %%
dfCat = read_csv('CATENTIDADRES.csv')
dfCat.head()
# Out:
#    EDO              DESCRIP
# 0    0      NO ESPECIFICADO
# 1    1       AGUASCALIENTES
# 2    2      BAJA CALIFORNIA
# 3    3  BAJA CALIFORNIA SUR
# 4    4             CAMPECHE

# %%
#Extraemos claves del Catalogo de Entidades
dfCat_subset = dfCat[['EDO', 'DESCRIP']]

#Lo usamos para Mapear el dataset principal
df['ENTRESIDENCIA'] = df['ENTRESIDENCIA'].map(dfCat_subset.set_index('EDO')['DESCRIP'])
df.head()
# Out:
#           CLUES   fechaalta  EDAD  CVEEDAD  SEXO    ENTRESIDENCIA  \
# ID
# 1   TSSSA003732  2022-10-25     7        5     1       TAMAULIPAS
# 2   ZSSSA013172  2022-11-08    22        5     2  NO ESPECIFICADO
# 3   ZSSSA001016  2022-11-05    10        4     2        ZACATECAS
# 4   ZSSSA000695  2022-10-26    17        5     1        ZACATECAS
# 5   ZSSSA000572  2022-11-02    18        5     2        ZACATECAS
#
#     MUNRESIDENCIA DERHAB  TIPOURGENCIA  MOTATE  ...  ENVIADOA  MP  \
# ID                                              ...
# 1              22     11             2       2  ...         4   8
# 2             999      0             1       1  ...         2   8
# 3              36      0             1       2  ...         4   8
# 4              22      0             2       2  ...         4   8
# 5              19     11             2       2  ...         4   8
#
#                                              AFECPRIN IRA  PLANEDA  \
# ID
# 1   GASTROENTERITIS Y COLITIS DE ORIGEN NO ESPECIF...   8        8
# 2       DOLOR ABDOMINAL LOCALIZADO EN PARTE SUPERIOR"   8        8
# 3                                    FARINGITIS AGUDA   2        8
# 4   CONTUSIÓN DE OTRAS PARTES DE LA MUÑECA Y DE LA...   8        8
# 5     SUPERVISIÓN DE EMBARAZO NORMAL NO ESPECIFICADO"   8        8
#
#    fechaingreso HORASESTANCIA MES_ESTADISTICO  hora_ingreso hora_alta
# ID
# 1    2022-10-25        000:13              10         13:37     13:50
# 2    2022-11-07        012:40              11         19:40     08:20
# 3    2022-11-05        000:15              11         15:15     15:30
# 4    2022-10-26        000:54              10         10:30     11:24
# 5    2022-11-02        000:29              11         06:41     07:10
#
# [5 rows x 21 columns]

# %%
df.head()
# Out:
#           CLUES   fechaalta  EDAD  CVEEDAD  SEXO    ENTRESIDENCIA  \
# ID
# 1   TSSSA003732  2022-10-25     7        5     1       TAMAULIPAS
# 2   ZSSSA013172  2022-11-08    22        5     2  NO ESPECIFICADO
# 3   ZSSSA001016  2022-11-05    10        4     2        ZACATECAS
# 4   ZSSSA000695  2022-10-26    17        5     1        ZACATECAS
# 5   ZSSSA000572  2022-11-02    18        5     2        ZACATECAS
#
#     MUNRESIDENCIA DERHAB  TIPOURGENCIA  MOTATE  ...  ENVIADOA  MP  \
# ID                                              ...
# 1              22     11             2       2  ...         4   8
# 2             999      0             1       1  ...         2   8
# 3              36      0             1       2  ...         4   8
# 4              22      0             2       2  ...         4   8
# 5              19     11             2       2  ...         4   8
#
#                                              AFECPRIN IRA  PLANEDA  \
# ID
# 1   GASTROENTERITIS Y COLITIS DE ORIGEN NO ESPECIF...   8        8
# 2       DOLOR ABDOMINAL LOCALIZADO EN PARTE SUPERIOR"   8        8
# 3                                    FARINGITIS AGUDA   2        8
# 4   CONTUSIÓN DE OTRAS PARTES DE LA MUÑECA Y DE LA...   8        8
# 5     SUPERVISIÓN DE EMBARAZO NORMAL NO ESPECIFICADO"   8        8
#
#    fechaingreso HORASESTANCIA MES_ESTADISTICO  hora_ingreso hora_alta
# ID
# 1    2022-10-25        000:13              10         13:37     13:50
# 2    2022-11-07        012:40              11         19:40     08:20
# 3    2022-11-05        000:15              11         15:15     15:30
# 4    2022-10-26        000:54              10         10:30     11:24
# 5    2022-11-02        000:29              11         06:41     07:10
#
# [5 rows x 21 columns]

# %%
dfUrgencia = read_csv('PROCEDIMIENTOS.txt', sep='|')

# %%
dfUrgencia.head()
# Out:
#    ID        CLUES   FECHAALTA  NUMPROMED PROMED TIPO
# 0   4  ZSSSA000695  2022-10-26          1   8907    D
# 1   6  SPSSA002992  2022-01-06          1   8904    D
# 2   7  TSSSA000092  2022-05-17          1   9929    T
# 3   7  TSSSA000092  2022-05-17          2   9921    T
# 4  13  SPSSA001102  2022-01-13          1   9199    D

# %%
dfCat = read_csv('CATTIPOPROCED.csv')

# %%
dfCat.head()
# Out:
#   IDTipoProced    TipoProced
# 0            D  DIAGNOSTICOS
# 1            Q   QUIRURGICOS
# 2            T  TERAPEUTICOS
# 3            F        MIXTOS

# %%
#Extraemos claves del Catalogo de Procedimiento
dfCat_subset = dfCat[['IDTipoProced', 'TipoProced']]

dfUrgencia['TIPO'] = dfUrgencia['TIPO'].map(dfCat_subset.set_index('IDTipoProced')['TipoProced'])
dfUrgencia.head()
# Out:
#    ID        CLUES   FECHAALTA  NUMPROMED PROMED          TIPO
# 0   4  ZSSSA000695  2022-10-26          1   8907  DIAGNOSTICOS
# 1   6  SPSSA002992  2022-01-06          1   8904  DIAGNOSTICOS
# 2   7  TSSSA000092  2022-05-17          1   9929  TERAPEUTICOS
# 3   7  TSSSA000092  2022-05-17          2   9921  TERAPEUTICOS
# 4  13  SPSSA001102  2022-01-13          1   9199  DIAGNOSTICOS

# %%
dfUrgencia['PROMED'] = dfUrgencia['PROMED'].drop_duplicates()

# %%
dfUrgencia = dfUrgencia.dropna()

# %%
dfUrgencia
# Out:
#               ID        CLUES   FECHAALTA  NUMPROMED PROMED          TIPO
# 0              4  ZSSSA000695  2022-10-26          1   8907  DIAGNOSTICOS
# 1              6  SPSSA002992  2022-01-06          1   8904  DIAGNOSTICOS
# 2              7  TSSSA000092  2022-05-17          1   9929  TERAPEUTICOS
# 3              7  TSSSA000092  2022-05-17          2   9921  TERAPEUTICOS
# 4             13  SPSSA001102  2022-01-13          1   9199  DIAGNOSTICOS
# ...          ...          ...         ...        ...    ...           ...
# 4159777  7014009  PLSSA002106  2022-04-10          2   00C8  TERAPEUTICOS
# 4161302  7017666  PLSSA002490  2022-05-01          2   9143  DIAGNOSTICOS
# 4173049  7039897  PLSSA008881  2022-05-20          1   244X   QUIRURGICOS
# 4177688  7049759  PLSSA016806  2022-01-12          1   3887   QUIRURGICOS
# 4178088  7050762  PLSSA016806  2022-05-26          1   8784  DIAGNOSTICOS
#
# [2265 rows x 6 columns]

# %%
#Se eliminan más columnas no utilizadas en el análisis
df = df.drop(['CLUES', 'DERHAB', 'MUNRESIDENCIA', 'HORASESTANCIA', 'TIPOCAMA', 'MP', 'PLANEDA', 'IRA', 'hora_ingreso', 'hora_alta'], axis=1)

# %%
dfCat = read_csv('CATSEXO.csv')
dfCat
# Out:
#    IdSexo          Descrip
# 0       0  NO ESPECIFICADO
# 1       1        MASCULINO
# 2       2         FEMENINO
# 3       3      INTERSEXUAL
# 4       9        SE IGNORA

# %%
#Extraemos claves del Catalogo de Entidades
dfCat_subset = dfCat[['IdSexo', 'Descrip']]

#Lo usamos para Mapear el dataset principal
df['SEXO'] = df['SEXO'].map(dfCat_subset.set_index('IdSexo')['Descrip'])
df.head()
# Out:
#      fechaalta  EDAD  CVEEDAD       SEXO    ENTRESIDENCIA  TIPOURGENCIA  \
# ID
# 1   2022-10-25     7        5  MASCULINO       TAMAULIPAS             2
# 2   2022-11-08    22        5   FEMENINO  NO ESPECIFICADO             1
# 3   2022-11-05    10        4   FEMENINO        ZACATECAS             1
# 4   2022-10-26    17        5  MASCULINO        ZACATECAS             2
# 5   2022-11-02    18        5   FEMENINO        ZACATECAS             2
#
#     MOTATE  ENVIADOA                                           AFECPRIN  \
# ID
# 1        2         4  GASTROENTERITIS Y COLITIS DE ORIGEN NO ESPECIF...
# 2        1         2      DOLOR ABDOMINAL LOCALIZADO EN PARTE SUPERIOR"
# 3        2         4                                   FARINGITIS AGUDA
# 4        2         4  CONTUSIÓN DE OTRAS PARTES DE LA MUÑECA Y DE LA...
# 5        2         4    SUPERVISIÓN DE EMBARAZO NORMAL NO ESPECIFICADO"
#
#    fechaingreso  MES_ESTADISTICO
# ID
# 1    2022-10-25               10
# 2    2022-11-07               11
# 3    2022-11-05               11
# 4    2022-10-26               10
# 5    2022-11-02               11

# %%
#Nos quedamos unicamente con los pacientes cuya edad está en años
df = df[df.CVEEDAD == 5]
df = df.drop(['CVEEDAD'], axis=1)

# %%
dfCat = read_csv('CatMotAtencionUrg.csv')
dfCat.head()
# Out:
#    IDMotAte                                 Descrip
# 0         1  ACCIDENTES, ENVENENAMIENTO Y VIOLENCIA
# 1         2                                  MÉDICA
# 2         3                       GINECO-OBSTÉTRICA
# 3         4                              PEDIÁTRICA
# 4         9                         NO ESPECIFICADO

# %%
#Extraemos claves del Catalogo de Motivo de Atención
dfCat_subset = dfCat[['IDMotAte', 'Descrip']]

#Lo usamos para Mapear el dataset principal
df['MOTATE'] = df['MOTATE'].map(dfCat_subset.set_index('IDMotAte')['Descrip'])
df.head()
# Out:
#      fechaalta  EDAD       SEXO    ENTRESIDENCIA  TIPOURGENCIA  \
# ID
# 1   2022-10-25     7  MASCULINO       TAMAULIPAS             2
# 2   2022-11-08    22   FEMENINO  NO ESPECIFICADO             1
# 4   2022-10-26    17  MASCULINO        ZACATECAS             2
# 5   2022-11-02    18   FEMENINO        ZACATECAS             2
# 6   2022-01-06     5  MASCULINO  SAN LUIS POTOSI             2
#
#                                     MOTATE  ENVIADOA  \
# ID
# 1                                   MÉDICA         4
# 2   ACCIDENTES, ENVENENAMIENTO Y VIOLENCIA         2
# 4                                   MÉDICA         4
# 5                                   MÉDICA         4
# 6   ACCIDENTES, ENVENENAMIENTO Y VIOLENCIA         4
#
#                                              AFECPRIN fechaingreso  \
# ID
# 1   GASTROENTERITIS Y COLITIS DE ORIGEN NO ESPECIF...   2022-10-25
# 2       DOLOR ABDOMINAL LOCALIZADO EN PARTE SUPERIOR"   2022-11-07
# 4   CONTUSIÓN DE OTRAS PARTES DE LA MUÑECA Y DE LA...   2022-10-26
# 5     SUPERVISIÓN DE EMBARAZO NORMAL NO ESPECIFICADO"   2022-11-02
# 6                            TRAUMATISMO DE LA CABEZA   2022-01-06
#
#     MES_ESTADISTICO
# ID
# 1                10
# 2                11
# 4                10
# 5                11
# 6                 1

# %%
dfCat = read_csv('CatTipoUrgencia.csv')
dfCat.head()
# Out:
#    IdTipoUrgencia                 Descrip
# 0               1     URGENCIA CALIFICADA
# 1               2  URGENCIA NO CALIFICADA
# 2               9         NO ESPECIFICADO

# %%
#Extraemos claves del Catalogo de Tipo de Urgencia
dfCat_subset = dfCat[['IdTipoUrgencia', 'Descrip']]

#Lo usamos para Mapear el dataset principal
df['TIPOURGENCIA'] = df['TIPOURGENCIA'].map(dfCat_subset.set_index('IdTipoUrgencia')['Descrip'])
df.head()
# Out:
#      fechaalta  EDAD       SEXO    ENTRESIDENCIA            TIPOURGENCIA  \
# ID
# 1   2022-10-25     7  MASCULINO       TAMAULIPAS  URGENCIA NO CALIFICADA
# 2   2022-11-08    22   FEMENINO  NO ESPECIFICADO     URGENCIA CALIFICADA
# 4   2022-10-26    17  MASCULINO        ZACATECAS  URGENCIA NO CALIFICADA
# 5   2022-11-02    18   FEMENINO        ZACATECAS  URGENCIA NO CALIFICADA
# 6   2022-01-06     5  MASCULINO  SAN LUIS POTOSI  URGENCIA NO CALIFICADA
#
#                                     MOTATE  ENVIADOA  \
# ID
# 1                                   MÉDICA         4
# 2   ACCIDENTES, ENVENENAMIENTO Y VIOLENCIA         2
# 4                                   MÉDICA         4
# 5                                   MÉDICA         4
# 6   ACCIDENTES, ENVENENAMIENTO Y VIOLENCIA         4
#
#                                              AFECPRIN fechaingreso  \
# ID
# 1   GASTROENTERITIS Y COLITIS DE ORIGEN NO ESPECIF...   2022-10-25
# 2       DOLOR ABDOMINAL LOCALIZADO EN PARTE SUPERIOR"   2022-11-07
# 4   CONTUSIÓN DE OTRAS PARTES DE LA MUÑECA Y DE LA...   2022-10-26
# 5     SUPERVISIÓN DE EMBARAZO NORMAL NO ESPECIFICADO"   2022-11-02
# 6                            TRAUMATISMO DE LA CABEZA   2022-01-06
#
#     MES_ESTADISTICO
# ID
# 1                10
# 2                11
# 4                10
# 5                11
# 6                 1

# %%
dfCat = read_csv('CatEnviado.csv')
dfCat.head()
# Out:
#    IDEnviado                 Descrip
# 0          1         HOSPITALIZACIÓN
# 1          2        CONSULTA EXTERNA
# 2          3  TRASLADO A OTRA UNIDAD
# 3          4               DOMICILIO
# 4          5      SALE POR DEFUNCIÓN

# %%
#Extraemos claves del Catalogo de Tipo de Urgencia
dfCat_subset = dfCat[['IDEnviado', 'Descrip']]

#Lo usamos para Mapear el dataset principal
df['ENVIADOA'] = df['ENVIADOA'].map(dfCat_subset.set_index('IDEnviado')['Descrip'])
df.head()
# Out:
#      fechaalta  EDAD       SEXO    ENTRESIDENCIA            TIPOURGENCIA  \
# ID
# 1   2022-10-25     7  MASCULINO       TAMAULIPAS  URGENCIA NO CALIFICADA
# 2   2022-11-08    22   FEMENINO  NO ESPECIFICADO     URGENCIA CALIFICADA
# 4   2022-10-26    17  MASCULINO        ZACATECAS  URGENCIA NO CALIFICADA
# 5   2022-11-02    18   FEMENINO        ZACATECAS  URGENCIA NO CALIFICADA
# 6   2022-01-06     5  MASCULINO  SAN LUIS POTOSI  URGENCIA NO CALIFICADA
#
#                                     MOTATE          ENVIADOA  \
# ID
# 1                                   MÉDICA         DOMICILIO
# 2   ACCIDENTES, ENVENENAMIENTO Y VIOLENCIA  CONSULTA EXTERNA
# 4                                   MÉDICA         DOMICILIO
# 5                                   MÉDICA         DOMICILIO
# 6   ACCIDENTES, ENVENENAMIENTO Y VIOLENCIA         DOMICILIO
#
#                                              AFECPRIN fechaingreso  \
# ID
# 1   GASTROENTERITIS Y COLITIS DE ORIGEN NO ESPECIF...   2022-10-25
# 2       DOLOR ABDOMINAL LOCALIZADO EN PARTE SUPERIOR"   2022-11-07
# 4   CONTUSIÓN DE OTRAS PARTES DE LA MUÑECA Y DE LA...   2022-10-26
# 5     SUPERVISIÓN DE EMBARAZO NORMAL NO ESPECIFICADO"   2022-11-02
# 6                            TRAUMATISMO DE LA CABEZA   2022-01-06
#
#     MES_ESTADISTICO
# ID
# 1                10
# 2                11
# 4                10
# 5                11
# 6                 1

# %%
df.to_csv('DataSetLimpio.csv')

# %%
#Comenzamos a trabajar con el Dataset Limpio

df = pd.read_csv('DataSetLimpio.csv')
df.head()
# Out:
#    ID   fechaalta  EDAD       SEXO    ENTRESIDENCIA            TIPOURGENCIA  \
# 0   1  2022-10-25     7  MASCULINO       TAMAULIPAS  URGENCIA NO CALIFICADA
# 1   2  2022-11-08    22   FEMENINO  NO ESPECIFICADO     URGENCIA CALIFICADA
# 2   4  2022-10-26    17  MASCULINO        ZACATECAS  URGENCIA NO CALIFICADA
# 3   5  2022-11-02    18   FEMENINO        ZACATECAS  URGENCIA NO CALIFICADA
# 4   6  2022-01-06     5  MASCULINO  SAN LUIS POTOSI  URGENCIA NO CALIFICADA
#
#                                    MOTATE          ENVIADOA  \
# 0                                  MÉDICA         DOMICILIO
# 1  ACCIDENTES, ENVENENAMIENTO Y VIOLENCIA  CONSULTA EXTERNA
# 2                                  MÉDICA         DOMICILIO
# 3                                  MÉDICA         DOMICILIO
# 4  ACCIDENTES, ENVENENAMIENTO Y VIOLENCIA         DOMICILIO
#
#                                             AFECPRIN fechaingreso  \
# 0  GASTROENTERITIS Y COLITIS DE ORIGEN NO ESPECIF...   2022-10-25
# 1      DOLOR ABDOMINAL LOCALIZADO EN PARTE SUPERIOR"   2022-11-07
# 2  CONTUSIÓN DE OTRAS PARTES DE LA MUÑECA Y DE LA...   2022-10-26
# 3    SUPERVISIÓN DE EMBARAZO NORMAL NO ESPECIFICADO"   2022-11-02
# 4                           TRAUMATISMO DE LA CABEZA   2022-01-06
#
#    MES_ESTADISTICO
# 0               10
# 1               11
# 2               10
# 3               11
# 4                1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6746216 entries, 0 to 6746215
# Data columns (total 11 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   ID               int64
#  1   fechaalta        object
#  2   EDAD             int64
#  3   SEXO             object
#  4   ENTRESIDENCIA    object
#  5   TIPOURGENCIA     object
#  6   MOTATE           object
#  7   ENVIADOA         object
#  8   AFECPRIN         object
#  9   fechaingreso     object
#  10  MES_ESTADISTICO  int64
# dtypes: int64(3), object(8)
# memory usage: 566.2+ MB

# %%
df['AFECPRIN'] = df['AFECPRIN'].astype(str)

# %% [markdown]
# Se observa que la media de edad es 31 años

# %%
df.describe().style.background_gradient(cmap='RdYlBu')
#Exportamos a CSV
dfResumen = df.describe()
dfResumen.to_csv('ResumenDatos.csv')

# %%
#Graficamos Histograma de Edades
plt.hist(df['EDAD'])
plt.show()

# %%
#Revisamos Tipo de variable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6746216 entries, 0 to 6746215
# Data columns (total 11 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   ID               int64
#  1   fechaalta        object
#  2   EDAD             int64
#  3   SEXO             object
#  4   ENTRESIDENCIA    object
#  5   TIPOURGENCIA     object
#  6   MOTATE           object
#  7   ENVIADOA         object
#  8   AFECPRIN         object
#  9   fechaingreso     object
#  10  MES_ESTADISTICO  int64
# dtypes: int64(3), object(8)
# memory usage: 566.2+ MB

# %%
plt.scatter(df['AFECPRIN'], df['EDAD'])

# Agregar etiquetas a los ejes
plt.xlabel("Aflicción")
plt.ylabel("Edad")

plt.show()

# %% [markdown]
# Vemos que los valores únicos en la columna Afeprin son demasiados por lo que se tomará una muestra menor

# %%
#Extraemos las 10 edades mas comunes
top_edades = df[df['EDAD'] >= df['EDAD'].quantile(0.9)]

top_edades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 687031 entries, 8 to 6746211
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ID               687031 non-null  int64
#  1   fechaalta        687031 non-null  object
#  2   EDAD             687031 non-null  int64
#  3   SEXO             687031 non-null  object
#  4   ENTRESIDENCIA    687031 non-null  object
#  5   TIPOURGENCIA     687031 non-null  object
#  6   MOTATE           687031 non-null  object
#  7   ENVIADOA         687031 non-null  object
#  8   AFECPRIN         687031 non-null  object
#  9   fechaingreso     687031 non-null  object
#  10  MES_ESTADISTICO  687031 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 62.9+ MB

# %%
#Extraemos los 25 valores mas populares
top_afecprin = df['AFECPRIN'].value_counts().nlargest(25).index

# Hacemos un subset con los valores mas populares
df_top = df[df['AFECPRIN'].isin(top_afecprin)]
plt.figure(figsize=(12, 6))
#Creamos el histograma usando unicamente los 10 primeros caracteres
plt.hist(df_top['AFECPRIN'].apply(lambda x: x[:16]), bins=25, edgecolor='black')

#Ponemos etiquetas
plt.xlabel("Afectación")
plt.ylabel("Frecuencia")

#Rotamos etiquetas
plt.xticks(rotation=45, ha="right")

plt.show()

# %%
# Set a larger figure size
plt.figure(figsize=(12, 6))

# Scatter plot
plt.scatter(df_top['AFECPRIN'].apply(lambda x: x[:16]), df_top['EDAD'], color='blue', label='EDAD')

# Add labels to the axes
plt.xlabel("Aflicción")
plt.ylabel("EDAD")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Show legend
plt.legend()

plt.show()

# %%
df_top['AFECPRIN'].value_counts()
# Out:
# SUPERVISIÓN DE EMBARAZO NORMAL NO ESPECIFICADO"                                       401604
# SUPERVISIÓN DE OTROS EMBARAZOS NORMALES"                                              181184
# FARINGITIS AGUDA                                                                      174294
# RINOFARINGITIS AGUDA [RESFRIADO COMÚN]"                                               154026
# INFECCIÓN DE VÍAS URINARIAS                                                           142420
# OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICADOS"                                     137325
# GASTROENTERITIS Y COLITIS DE ORIGEN NO ESPECIFICADO"                                  129553
# HIPERTENSIÓN ESENCIAL (PRIMARIA)"                                                     124500
# COVID-19                                                                              117806
# DIABETES MELLITUS TIPO 2                                                               86924
# EFECTO TÓXICO DEL VENENO DE ESCORPIÓN"                                                 84581
# SUPERVISIÓN DE PRIMER EMBARAZO NORMAL"                                                 75485
# FALSO TRABAJO DE PARTO A LAS 37 Y MÁS SEMANAS COMPLETAS DE GESTACIÓN"                  73400
# TRAUMATISMOS SUPERFICIALES MÚLTIPLES                                                   73280
# OTRAS GASTROENTERITIS Y COLITIS DE ORIGEN INFECCIOSO"                                  72901
# AMENAZA DE ABORTO"                                                                     62248
# EMBARAZO CONFIRMADO"                                                                   57102
# OTRAS INFECCIONES AGUDAS DE SITIOS MÚLTIPLES DE LAS VÍAS RESPIRATORIAS SUPERIORES"     53238
# INFECCIÓN NO ESPECIFICADA DE LAS VÍAS URINARIAS EN EL EMBARAZO"                        50830
# DOLOR ABDOMINAL LOCALIZADO EN PARTE SUPERIOR"                                          47933
# CEFALEA"                                                                               47667
# DIABETES MELLITUS NO ESPECIFICADA                                                      44981
# FIEBRE                                                                                 44728
# TRAUMATISMO INTRACRANEAL                                                               44426
# GASTRITIS                                                                              43684
# Name: AFECPRIN, dtype: int64

# %%
#Boxplot de EDAD
plt.figure(figsize=(8, 6))
plt.boxplot(df['EDAD'], vert=False)
plt.xlabel("EDAD")

plt.show()

# %%
#Histograma de edades post limpieza

plt.figure(figsize=(12, 6))
plt.hist(df_top['EDAD'], bins=25, edgecolor='black')


#Rotamos etiquetas
plt.xticks(rotation=45, ha="right")

plt.show()

# %%
from scipy.stats import shapiro

stat, valor_p = shapiro(df['EDAD'])
print(f"Estadístico de Shapiro Wilk: {stat}, valor_p: {valor_p}")
# Out:
# Estadístico de Shapiro Wilk: 0.9574047327041626, valor_p: 0.0

# %%
#Histograma de entidades

plt.figure(figsize=(12, 6))
plt.hist(df['ENTRESIDENCIA'], bins=33, edgecolor='black')


#Rotamos etiquetas
plt.xticks(rotation=45, ha="right")

plt.show()
