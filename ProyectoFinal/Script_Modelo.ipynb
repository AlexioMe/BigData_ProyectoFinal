# %%
# !pip install pycaret --user
# Out:
# ...
#   Using cached pycaret-3.2.0-py3-none-any.whl (484 kB)
# ...
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# ...
#   Using cached psutil-5.9.7-cp37-abi3-win_amd64.whl (252 kB)
# ...
#   Using cached imbalanced_learn-0.11.0-py3-none-any.whl (235 kB)
# ...
#   Using cached category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
# ...
#   Using cached pyod-1.1.2-py3-none-any.whl
# ...
#   Using cached importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# ...
#   Using cached kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
# ...
#   Using cached lightgbm-4.2.0-py3-none-win_amd64.whl (1.3 MB)
# ...
#   Using cached xxhash-3.4.1-cp39-cp39-win_amd64.whl (29 kB)
# ...
#   Using cached plotly_resampler-0.9.1-py3-none-any.whl (73 kB)
# ...
#   Using cached tbats-1.1.3-py3-none-any.whl (44 kB)
# ...
#   Using cached sktime-0.21.1-py3-none-any.whl (17.1 MB)
# ...
#   Using cached pmdarima-2.0.4-cp39-cp39-win_amd64.whl (614 kB)
# ...
#   Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# ...
#   Using cached schemdraw-0.15-py3-none-any.whl (106 kB)
# ...

# %%
# !pip install markupsafe==2.0.1

# %%
from pycaret.classification import *

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import jinja2
import statsmodels.api as sm;
import pickle
import warnings

# %%
from pandas import DataFrame, read_csv
df = read_csv('DataSetLimpio_Num.csv', sep=',', index_col=['ID'])
df.head()
# Out:
#      fechaalta  EDAD  CVEEDAD  SEXO  ENTRESIDENCIA  TIPOURGENCIA  MOTATE  \
# ID
# 1   2022-10-25     7        5     1             28             2       2
# 2   2022-11-08    22        5     2              0             1       1
# 3   2022-11-05    10        4     2             32             1       2
# 4   2022-10-26    17        5     1             32             2       2
# 5   2022-11-02    18        5     2             32             2       2
#
#     ENVIADOA AFECPRIN fechaingreso  MES_ESTADISTICO
# ID
# 1          4     A099   2022-10-25               10
# 2          2     R101   2022-11-07               11
# 3          4     J029   2022-11-05               11
# 4          4     S602   2022-10-26               10
# 5          4     Z349   2022-11-02               11

# %%
#from sklearn.model_selection import train_test_split

# Divide tus datos estratificadamente
#train_data, test_data = train_test_split(df, test_size=0.2, stratify=df["MOTATE"], random_state=42)

#Toma una muestra aleatoria de tus datos
#data_sample = df.sample(frac=0.1, random_state=42)

# %%
clasificacion = setup(
    data=df,
    target="MOTATE",
    session_id=123,
    fold_shuffle=True,  # Esto activa el barajado de los pliegues
    fold_strategy="stratifiedkfold",  # Puedes cambiar esto según tus necesidades
    numeric_features=[],  # Puedes especificar las características numéricas si es necesario
)
# Out:
# <style type="text/css">
# #T_35472_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_35472">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35472_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_35472_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35472_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35472_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_35472_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_35472_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35472_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_35472_row1_col1" class="data row1 col1" >MOTATE</td>
#     </tr>
#     <tr>
#       <th id="T_35472_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
remove_metric("Kappa")
remove_metric("MCC")
mejor_modelo = compare_models()

# %%
modelo = create_model("et") #Se crea el modelo con el mejor modelo en base a la comparativa anterior
print(modelo)

# %%
evaluate_model(modelo) # Se evalua el modelo final
